# %%
import pandas as pd

# %%
from warnings import filterwarnings
filterwarnings('ignore')
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('50_Startups.csv')

# %%
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isna().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'STATE', 'PROFIT'], dtype='object')

# %%
plt.figure(figsize=(16,8))
plt.title("Hi")
sns.scatterplot(data=df,x='RND',y='PROFIT')
plt.grid()
plt.show()

# %% [markdown]
# Do the EDA in PYHON
# Step1 : -Seperate Categorical and Continuous features

# %%
df.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'STATE', 'PROFIT'], dtype='object')

# %%
df.dtypes
# Out:
# RND       float64
# ADMIN     float64
# MKT       float64
# STATE      object
# PROFIT    float64
# dtype: object

# %%
X=df[df['PROFIT']>150000][['ADMIN','PROFIT']]
# Out:
#        ADMIN     PROFIT
# 0  136897.80  192261.83
# 1  151377.59  191792.06
# 2  101145.55  191050.39
# 3  118671.85  182901.99
# 4   91391.77  166187.94
# 5   99814.71  156991.12
# 6  147198.87  156122.51
# 7  145530.06  155752.60
# 8  148718.95  152211.77

# %%
df[df['ADMIN']>150000]
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 1   162597.70  151377.59  443898.53  California  191792.06
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# 19   86419.70  153514.11       0.00    New York  122776.86
# 21   78389.47  153773.43  299737.29    New York  111313.02
# 28   66051.52  182645.56  118148.20     Florida  103282.38
# 29   65605.48  153032.06  107138.38    New York  101004.64
# 31   61136.38  152701.92   88218.23    New York   97483.56
# 34   46426.07  157693.92  210797.67  California   96712.80
# 44   22177.74  154806.14   28334.72  California   65200.33

# %%
cat=df.columns[df.dtypes=='object']

# %%
con=df.columns[df.dtypes!='object']

# %%
cat
# Out:
# Index(['STATE'], dtype='object')

# %%
con
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'PROFIT'], dtype='object')

# %%
df['STATE'].value_counts()
# Out:
# STATE
# New York      17
# California    17
# Florida       16
# Name: count, dtype: int64

# %%
df['STATE'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='STATE'>

# %%
df['STATE'].value_counts().plot(kind='bar',
                                xlabel='State',
                                ylabel='Count',
                                title='State Graph')
# Out:
# <Axes: title={'center': 'State Graph'}, xlabel='State', ylabel='Count'>

# %%
df['STATE'].value_counts().plot(kind='bar',
                                xlabel='State',
                                ylabel='Count',
                                title='State Graph',
                                figsize=(16,8))
# Out:
# <Axes: title={'center': 'State Graph'}, xlabel='State', ylabel='Count'>

# %%
df['STATE'].value_counts().plot(kind='barh',
                                xlabel='State',
                                ylabel='Count',
                                title='State Graph'
                                )
# Out:
# <Axes: title={'center': 'State Graph'}, xlabel='State', ylabel='Count'>

# %%
df['STATE'].value_counts().plot(kind='pie',
                                )
# Out:
# <Axes: ylabel='count'>

# %%
for i in cat:
    df[i].value_counts().plot(kind='bar',
                              title=f"Countplot for {i}")
    plt.show()

# %% [markdown]
# For Numerical Data , use Histogram

# %% [markdown]
# You need to use Seaborn Library

# %%
con
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'PROFIT'], dtype='object')

# %% [markdown]
# Let Find profit of the distribution

# %%
sns.histplot(data=df,x='PROFIT',kde=True)
# Out:
# <Axes: xlabel='PROFIT', ylabel='Count'>

# %%
sns.scatterplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# As there are 4 Continuous Feature, we can use FOR LOOP to plt all the graph

# %%
for i in con:
    print(i)
    sns.histplot(data=df,x=i,kde=True)
    #plt.figure(16,8)
    plt.title(f'Histogram is for {i}')
    plt.show()
# Out:
# RND
# ADMIN
# MKT
# PROFIT

# %%
con
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'PROFIT'], dtype='object')

# %%
a=len(df)
import math as m
m.sqrt(a)
# Out:
# 7.0710678118654755

# %%
for i in con:
    plt.figure(figsize=(16,8))
    plt.title(f'This is for {i}')
    sns.histplot(data=df,x=i,kde=True)
    plt.grid()
    plt.show()

# %% [markdown]
# Read the data

# %%
from warnings import filterwarnings
filterwarnings('ignore')
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('laptopPrice.csv')

# %% [markdown]
# Check the Basic information about data

# %%
import os

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.shape
# Out:
# (823, 19)

# %%
df.isna().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 21

# %%
21/823
# Out:
# 0.02551640340218712

# %% [markdown]
# df.dtypes()

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
cat=df.columns[df.dtypes=='object']

# %%
con=df.columns[df.dtypes!='object']

# %%
con
# Out:
# Index(['Price', 'Number of Ratings', 'Number of Reviews'], dtype='object')

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.shape
# Out:
# (823, 19)

# %%
df[cat]
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df[cat].describe().T
# Out:
#                 count unique      top freq
# brand             823      8     ASUS  249
# processor_brand   823      3    Intel  610
# processor_name    823     11  Core i5  290
# processor_gnrtn   823      8     11th  334
# ram_gb            823      4     8 GB  418
# ram_type          823      6     DDR4  709
# ssd               823      7   512 GB  398
# hdd               823      4     0 GB  621
# os                823      3  Windows  779
# os_bit            823      2   64-bit  714
# graphic_card_gb   823      5     0 GB  577
# weight            823      3   Casual  520
# warranty          823      4   1 year  509
# Touchscreen       823      2       No  726
# msoffice          823      2       No  542
# rating            823      5  4 stars  444

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
df['brand'].value_counts()
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
df['con'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'con'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df['con'].describe()
#
# ...

# %%
df[con].describe().T
# Out:
#                    count          mean           std      min      25%  \
# Price              823.0  76745.177400  45101.790525  16990.0  46095.0
# Number of Ratings  823.0    315.301337   1047.382654      0.0      0.0
# Number of Reviews  823.0     37.609964    121.728017      0.0      0.0
#
#                        50%      75%       max
# Price              64990.0  89636.0  441990.0
# Number of Ratings     17.0    139.5   15279.0
# Number of Reviews      2.0     18.0    1947.0

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# Intel    610
# AMD      189
# M1        24
# Name: count, dtype: int64

# %%
df['warranty'].unique()
# Out:
# array(['No warranty', '1 year', '2 years', '3 years'], dtype=object)

# %%
df['warranty'].value_counts()
# Out:
# warranty
# 1 year         509
# No warranty    278
# 2 years         23
# 3 years         13
# Name: count, dtype: int64

# %% [markdown]
# 4)Univariate Analysis i.e. this is for 1 variable any 1 categorical or continuous variable

# %% [markdown]
# For Cotegorical, we will use bar or pie chart
# For Continuous, we will use Histogram

# %%
df[cat]
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
cat
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating'],
#       dtype='object')

# %%
df['brand'].value_counts()
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
df['brand'].value_counts().plot(kind='bar',
                                ylabel='Count',
                                title="Brand wise Count")
# Out:
# <Axes: title={'center': 'Brand wise Count'}, xlabel='brand', ylabel='Count'>

# %%
for i in cat:
    df[i].value_counts().plot(kind='bar',
                              title=f'Count for {i}')
    plt.show()

# %% [markdown]
# For Continuous Feature, we use Histogram

# %%
con
# Out:
# Index(['Price', 'Number of Ratings', 'Number of Reviews'], dtype='object')

# %%
sns.histplot(data=df,x='Price',kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
df.shape
# Out:
# (823, 19)

# %%
import math as m
m.sqrt(823)
# Out:
# 28.687976575562104

# %%
df.__le__
# Out:
# <bound method OpsMixin.__le__ of       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
for i in con:
    plt.figure(figsize=(16,8))
    plt.title("Shaurya")
    sns.histplot(data=df,x=i,kde=True)
    plt.grid()
    plt.show()

# %% [markdown]
# Bi varint Analysis
#
# Continuous ~ Continuous:
# scatter Plot & Corelation Chart
#
# Continuous ~ Categorical:
# Box plot
#
# Cotegorical ~ Categorical :
# Crosstab

# %%
con
# Out:
# Index(['Price', 'Number of Ratings', 'Number of Reviews'], dtype='object')

# %%
plt.figure(figsize=(16,8))
plt.title("Price v/s Number of Ratings")
sns.scatterplot(data=df,x='Price',y='Number of Ratings')
plt.show()

# %%
#Getting Corelation of data
cor=df[con].corr()
cor
# Out:
#                       Price  Number of Ratings  Number of Reviews
# Price              1.000000          -0.140392          -0.148738
# Number of Ratings -0.140392           1.000000           0.989626
# Number of Reviews -0.148738           0.989626           1.000000

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
cat
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating'],
#       dtype='object')

# %%
con
# Out:
# Index(['Price', 'Number of Ratings', 'Number of Reviews'], dtype='object')

# %% [markdown]
# Boxplot

# %%
sns.boxplot(data=df,x='brand',y='Price')
# Out:
# <Axes: xlabel='brand', ylabel='Price'>

# %%
cat
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating'],
#       dtype='object')

# %%
for i in cat:
    sns.boxplot(data=df,x=i,y='Price')
    plt.show()

# %%
cat
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating'],
#       dtype='object')

# %% [markdown]
# Bi Variant Analysis for Categorical v/s Categorical

# %%
cat
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating'],
#       dtype='object')

# %%
cro=pd.crosstab(df['ram_gb'],df['warranty'])

# %%
cro
# Out:
# warranty  1 year  2 years  3 years  No warranty
# ram_gb
# 16 GB        115        7        3           52
# 32 GB          2        0        0            0
# 4 GB         134        2        4           86
# 8 GB         258       14        6          140

# %%
sns.heatmap(cro,annot=True,fmt='d')
# Out:
# <Axes: xlabel='warranty', ylabel='ram_gb'>

# %%
s1=pd.crosstab(df['brand'],df['rating'])

# %%
sns.heatmap(s1,annot=True,fmt='d')
# Out:
# <Axes: xlabel='rating', ylabel='brand'>

# %%
sns.pairplot(data=df)

# %%
con
# Out:
# Index(['Price', 'Number of Ratings', 'Number of Reviews'], dtype='object')

# %%
# Using Categorical Fature

sns.pairplot(df,hue='brand')

# %%
sns.pairplot(df)
